# %%
import pandas as pd

# %%
df = pd.read_csv("Original_data_with_more_rows.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0           0  female     group B   bachelor's degree      standard
# 1           1  female     group C        some college      standard
# 2           2  female     group B     master's degree      standard
# 3           3    male     group A  associate's degree  free/reduced
# 4           4    male     group C        some college      standard
#
#     TestPrep  MathScore  ReadingScore  WritingScore
# 0       none         72            72            74
# 1  completed         69            90            88
# 2       none         90            95            93
# 3       none         47            57            44
# 4       none         76            78            75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    30641 non-null  int64
#  1   Gender        30641 non-null  object
#  2   EthnicGroup   30641 non-null  object
#  3   ParentEduc    30641 non-null  object
#  4   LunchType     30641 non-null  object
#  5   TestPrep      30641 non-null  object
#  6   MathScore     30641 non-null  int64
#  7   ReadingScore  30641 non-null  int64
#  8   WritingScore  30641 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 2.1+ MB

# %%
drop_columns = ["Unnamed: 0","EthnicGroup","LunchType"]

# %%
#2 tpys of drop data 
#df_clean= df.drop(columns=drop_columns)
#or 
#df.drop(columns=drop_columns,inplace=True)

# %%
df.drop(columns=drop_columns,inplace=True)

# %%
df.head(1)
# Out:
#    Gender         ParentEduc TestPrep  MathScore  ReadingScore  WritingScore
# 0  female  bachelor's degree     none         72            72            74

# %% [markdown]
# ## DATA RENAME

# %%
df.rename(columns={"ParentEduc":"Parent_Education","TestPrep":"Test_Preparatıon"})
# Out:
#        Gender    Parent_Education Test_Preparatıon  MathScore  ReadingScore  \
# 0      female   bachelor's degree             none         72            72
# 1      female        some college        completed         69            90
# 2      female     master's degree             none         90            95
# 3        male  associate's degree             none         47            57
# 4        male        some college             none         76            78
# ...       ...                 ...              ...        ...           ...
# 30636    male    some high school             none         56            47
# 30637    male  associate's degree             none         74            75
# 30638    male        some college             none         36            29
# 30639    male    some high school        completed         43            34
# 30640  female  associate's degree             none         52            68
#
#        WritingScore
# 0                74
# ...

# %%
df.duplicated().value_counts()
#True      1356 there is 1356 row
# Out:
# False    29285
# True      1356
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30635    False
# 30636    False
# 30638    False
# 30639    False
# 30640    False
# Length: 29285, dtype: bool

# %%
#Length: 29285 but df show us 30640 row its definetly false we need to fix it
df.reset_index(inplace=True)

# %%
df
# Out:
#        index  Gender          ParentEduc   TestPrep  MathScore  ReadingScore  \
# 0          0  female   bachelor's degree       none         72            72
# 1          1  female        some college  completed         69            90
# 2          2  female     master's degree       none         90            95
# 3          3    male  associate's degree       none         47            57
# 4          4    male        some college       none         76            78
# ...      ...     ...                 ...        ...        ...           ...
# 29280  30635    male    some high school  completed         64            59
# 29281  30636    male    some high school       none         56            47
# 29282  30638    male        some college       none         36            29
# 29283  30639    male    some high school  completed         43            34
# 29284  30640  female  associate's degree       none         52            68
#
#        WritingScore
# 0                74
# ...

# %%
## İs there any Nan values in our data

# %%
df.isna().sum()
# Out:
# index           0
# Gender          0
# ParentEduc      0
# TestPrep        0
# MathScore       0
# ReadingScore    0
# WritingScore    0
# dtype: int64

# %%
df["Gender"].replace("male",value="M",inplace=True)
df["Gender"].replace("female",value="F",inplace=True)
                        #or
      #df["Gender"] = df["Gender"].replace({"male": "M", "female": "F"})

                         #or
     #s = df["Gender"].astype("string").str.strip().str.lower()
    
     #df["Gender"] = s.map({"male": "M", "female": "F"})
